# %% [markdown]
# <a href="https://colab.research.google.com/github/igorSant0/YOLOuking-For-/blob/main/core/yolo/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
